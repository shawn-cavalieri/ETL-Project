# %%
import pandas as pd
import numpy as np
import pybaseball as pb
from pybaseball import pitching_stats

# %%
data = pitching_stats(2012,2018)

# %%
data.head(50)
# Out:
#       Season               Name          Team   Age     W     L   ERA  WAR  \
# 297   2018.0       Jacob deGrom          Mets  30.0  10.0   9.0  1.70  9.0
# 445   2015.0    Clayton Kershaw       Dodgers  27.0  16.0   7.0  2.13  8.6
# 315   2014.0    Clayton Kershaw       Dodgers  26.0  21.0   3.0  1.77  7.9
# 1009  2017.0         Chris Sale       Red Sox  28.0  17.0   8.0  2.90  7.6
# 679   2018.0       Max Scherzer     Nationals  33.0  18.0   7.0  2.53  7.5
# 511   2017.0       Corey Kluber       Indians  31.0  18.0   4.0  2.25  7.2
# 619   2014.0       Corey Kluber       Indians  28.0  18.0   9.0  2.44  7.2
# 338   2013.0    Clayton Kershaw       Dodgers  25.0  16.0   9.0  1.83  7.2
# 314   2015.0       Jake Arrieta          Cubs  29.0  22.0   6.0  1.77  7.0
# 780   2012.0   Justin Verlander        Tigers  29.0  17.0   8.0  2.64  6.9
# 515   2013.0        Matt Harvey          Mets  24.0   9.0   5.0  2.27  6.9
# ...

# %%
data_2019 = pitching_stats(2019, qual=30)

# %%
data_2019
# Out:
#      Season              Name       Team   Age     W     L   ERA  WAR     G  \
# 29   2019.0       Gerrit Cole     Astros  28.0  20.0   5.0  2.50  7.4  33.0
# 21   2019.0      Jacob deGrom       Mets  31.0  11.0   8.0  2.43  7.0  32.0
# 125  2019.0        Lance Lynn    Rangers  32.0  16.0  11.0  3.67  6.8  33.0
# 53   2019.0      Max Scherzer  Nationals  34.0  11.0   7.0  2.92  6.5  27.0
# 31   2019.0  Justin Verlander     Astros  36.0  21.0   6.0  2.58  6.4  34.0
# ..      ...               ...        ...   ...   ...   ...   ...  ...   ...
# 442  2019.0        David Hess    Orioles  25.0   1.0  10.0  7.09 -0.8  23.0
# 414  2019.0     Derek Holland      - - -  32.0   2.0   5.0  6.08 -1.0  51.0
# 288  2019.0      Jesus Tinoco    Rockies  24.0   0.0   3.0  4.75 -1.0  24.0
# 456  2019.0     Edwin Jackson      - - -  35.0   3.0  10.0  9.58 -1.1  18.0
# 457  2019.0       Dan Straily    Orioles  30.0   2.0   4.0  9.82 -1.1  14.0
#
# ...

# %%
data_2019.describe()
# Out:
#        Season         Age           W           L         ERA         WAR  \
# count   457.0  457.000000  457.000000  457.000000  457.000000  457.000000
# mean   2019.0   28.260394    4.927790    4.814004    4.452801    0.990372
# std       0.0    3.546067    4.176117    3.490335    1.335873    1.411293
# min    2019.0   19.000000    0.000000    0.000000    1.190000   -1.100000
# 25%    2019.0   26.000000    2.000000    2.000000    3.600000    0.000000
# 50%    2019.0   28.000000    4.000000    4.000000    4.400000    0.600000
# 75%    2019.0   31.000000    6.000000    7.000000    5.250000    1.500000
# max    2019.0   42.000000   21.000000   17.000000    9.820000    7.400000
#
#                 G          GS          CG         ShO  ...  wSL/C (pi)  \
# count  457.000000  457.000000  457.000000  457.000000  ...  389.000000
# mean    38.932166   10.183807    0.096280    0.056893  ...   -0.260591
# std     18.622690   11.883624    0.379761    0.258711  ...    5.691129
# ...

# %%
df_2019 = pd.DataFrame(data_2019, columns = ['Name', 'Team', 'Age', 'IP', 'W', 'L', 'ERA', 'WAR', 'GS'])

df_2019 = df_2019.set_index('Name')

df_2019
# Out:
#                        Team   Age     IP     W     L   ERA  WAR    GS
# Name
# Gerrit Cole          Astros  28.0  212.1  20.0   5.0  2.50  7.4  33.0
# Jacob deGrom           Mets  31.0  204.0  11.0   8.0  2.43  7.0  32.0
# Lance Lynn          Rangers  32.0  208.1  16.0  11.0  3.67  6.8  33.0
# Max Scherzer      Nationals  34.0  172.1  11.0   7.0  2.92  6.5  27.0
# Justin Verlander     Astros  36.0  223.0  21.0   6.0  2.58  6.4  34.0
# ...                     ...   ...    ...   ...   ...   ...  ...   ...
# David Hess          Orioles  25.0   80.0   1.0  10.0  7.09 -0.8  14.0
# Derek Holland         - - -  32.0   84.1   2.0   5.0  6.08 -1.0   8.0
# Jesus Tinoco        Rockies  24.0   36.0   0.0   3.0  4.75 -1.0   0.0
# Edwin Jackson         - - -  35.0   67.2   3.0  10.0  9.58 -1.1  13.0
# Dan Straily         Orioles  30.0   47.2   2.0   4.0  9.82 -1.1   8.0
#
# [457 rows x 8 columns]

# %%
data_2012_2019 = pitching_stats(2012,2019, qual=100)

# %%
data_2012_2019
# Out:
#       Season             Name       Team   Age     W     L   ERA  WAR     G  \
# 4     2018.0     Jacob deGrom       Mets  30.0  10.0   9.0  1.70  9.0  32.0
# 12    2015.0  Clayton Kershaw    Dodgers  27.0  16.0   7.0  2.13  8.6  33.0
# 7     2014.0  Clayton Kershaw    Dodgers  26.0  21.0   3.0  1.77  7.9  27.0
# 109   2017.0       Chris Sale    Red Sox  28.0  17.0   8.0  2.90  7.6  32.0
# 41    2018.0     Max Scherzer  Nationals  33.0  18.0   7.0  2.53  7.5  33.0
# ...      ...              ...        ...   ...   ...   ...   ...  ...   ...
# 1113  2015.0    Kyle Kendrick    Rockies  30.0   7.0  13.0  6.32 -0.9  27.0
# 1089  2013.0    Lucas Harrell     Astros  28.0   6.0  17.0  5.86 -0.9  36.0
# 1087  2016.0    James Shields      - - -  34.0   6.0  19.0  5.85 -1.0  33.0
# 1094  2017.0     Mike Pelfrey  White Sox  33.0   3.0  12.0  5.93 -1.0  34.0
# 609   2013.0    Jason Marquis     Padres  34.0   9.0   5.0  4.05 -1.3  20.0
#
# ...

# %%
df_2012_2019 = pd.DataFrame(data_2012_2019, columns = ['Name', 'Team', 'Age', 'IP', 'W', 'L', 'ERA', 'WAR', 'GS'])

df_2012_2019 = df_2012_2019.set_index('Name')

df_2012_2019
# Out:
#                       Team   Age     IP     W     L   ERA  WAR    GS
# Name
# Jacob deGrom          Mets  30.0  217.0  10.0   9.0  1.70  9.0  32.0
# Clayton Kershaw    Dodgers  27.0  232.2  16.0   7.0  2.13  8.6  33.0
# Clayton Kershaw    Dodgers  26.0  198.1  21.0   3.0  1.77  7.9  27.0
# Chris Sale         Red Sox  28.0  214.1  17.0   8.0  2.90  7.6  32.0
# Max Scherzer     Nationals  33.0  220.2  18.0   7.0  2.53  7.5  33.0
# ...                    ...   ...    ...   ...   ...   ...  ...   ...
# Kyle Kendrick      Rockies  30.0  142.1   7.0  13.0  6.32 -0.9  27.0
# Lucas Harrell       Astros  28.0  153.2   6.0  17.0  5.86 -0.9  22.0
# James Shields        - - -  34.0  181.2   6.0  19.0  5.85 -1.0  33.0
# Mike Pelfrey     White Sox  33.0  120.0   3.0  12.0  5.93 -1.0  21.0
# Jason Marquis       Padres  34.0  117.2   9.0   5.0  4.05 -1.3  20.0
#
# [1125 rows x 8 columns]
